# %%
lbda = lambda x, y : (x+y)
print(type(lbda))
print(lbda(4, 3))
# Out:
# <class 'function'>
# 7

# %%
""" 
map() - applies function to all elements in the collection
"""
numbers = [2, 5, 7, 9, 12]
list(map(lambda x:x**2, numbers))
# Out:
# [4, 25, 49, 81, 144]
