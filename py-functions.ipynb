# %%
def my_function(name="John Doe"):
    return "Hello " + name

if __name__ == "__main__":
    """ this will take given name value"""
    print(my_function("Sandeep"))

    """ this will take default name as null"""
    print(my_function(""))

    """ this will take default name value"""
    print(my_function())
# Out:
# Hello Sandeep
# Hello
# Hello John Doe
